# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
df = pd.read_csv('/Users/a666/Desktop/2022project-main/stack-overflow-developer-survey-2022/survey_results_public.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# ...

# %%
select =[
    'Country', 'Age', 'Gender','EdLevel',
    'LearnCode','YearsCode',
    'YearsCodePro', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
    'OpSysProfessional use', 'OpSysPersonal use',
    'Blockchain','CompTotal', 'CompFreq'
]

# %%
survey_df = df[select].copy()

# %%
survey_df
# Out:
#                                                  Country              Age  \
# 0                                                    NaN              NaN
# 1                                                 Canada              NaN
# 2      United Kingdom of Great Britain and Northern I...  25-34 years old
# 3                                                 Israel  35-44 years old
# 4                               United States of America  25-34 years old
# ...                                                  ...              ...
# 73263                                            Nigeria  25-34 years old
# 73264                           United States of America  25-34 years old
# 73265                           United States of America  55-64 years old
# 73266  United Kingdom of Great Britain and Northern I...  55-64 years old
# 73267                                             Canada  25-34 years old
#
#       Gender                                          EdLevel  \
# ...

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 71771 non-null  object
#  1   Age                     70946 non-null  object
#  2   Gender                  70853 non-null  object
#  3   EdLevel                 71571 non-null  object
#  4   LearnCode               71580 non-null  object
#  5   YearsCode               71331 non-null  object
#  6   YearsCodePro            51833 non-null  object
#  7   LanguageHaveWorkedWith  70975 non-null  object
#  8   LanguageWantToWorkWith  67027 non-null  object
#  9   OpSysProfessional use   65503 non-null  object
#  10  OpSysPersonal use       70963 non-null  object
#  11  Blockchain              71071 non-null  object
#  12  CompTotal               38422 non-null  float64
#  13  CompFreq                44425 non-null  object
# ...

# %%
survey_df['Gender'].value_counts()
# Out:
# Man                                                                                   64607
# Woman                                                                                  3399
# Prefer not to say                                                                      1172
# Non-binary, genderqueer, or gender non-conforming                                       704
# Or, in your own words:                                                                  279
# Man;Non-binary, genderqueer, or gender non-conforming                                   235
# Man;Or, in your own words:                                                              171
# Woman;Non-binary, genderqueer, or gender non-conforming                                 160
# Man;Woman;Non-binary, genderqueer, or gender non-conforming                              31
# Man;Woman                                                                                24
# ...

# %%
matplotlib.rcParams['font.family']='SimHei'
matplotlib.rcParams['font.sans-serif']=['SimHei']
plt.pie(survey_df['Gender'].value_counts()[0:2],
        labels=["男","女"],
        autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fea04100760>,
# ...
#  [Text(-1.086467509574117, 0.17201264674382563, '男'),
#   Text(1.0864675115872402, -0.17201263402852174, '女')],
#  [Text(-0.592618641585882, 0.0938250800420867, '95.0%'),
#   Text(0.5926186426839491, -0.09382507310646639, '5.0%')])
# findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans.
# /Users/a666/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30007 (\N{CJK UNIFIED IDEOGRAPH-7537}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/a666/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22899 (\N{CJK UNIFIED IDEOGRAPH-5973}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 主要国家和地区

# %%
df['Country'].value_counts(normalize=True)
# Out:
# United States of America                                0.188697
# India                                                   0.092503
# Germany                                                 0.075170
# United Kingdom of Great Britain and Northern Ireland    0.058380
# Canada                                                  0.034694
#                                                           ...
# Monaco                                                  0.000014
# Djibouti                                                0.000014
# Seychelles                                              0.000014
# Solomon Islands                                         0.000014
# Saint Kitts and Nevis                                   0.000014
# Name: Country, Length: 180, dtype: float64

# %%
df['Country'].value_counts()[0:5].plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 学习如何编写代码

# %%
df['LearnCode'].value_counts(normalize=True)
# Out:
# School (i.e., University, College, etc)                                                                                                                                                                                      0.051257
# Other online resources (e.g., videos, blogs, forum)                                                                                                                                                                          0.045991
# Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc)                                                                                                           0.040137
# Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc)                                                                                                                                  0.037678
# ...

# %%
df['LearnCode'].value_counts()[0:8].plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 教育程度

# %%
df['EdLevel'].value_counts(normalize=True)
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          0.423020
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       0.216373
# Some college/university study without earning a degree                                0.130304
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    0.110436
# Associate degree (A.A., A.S., etc.)                                                   0.031242
# Other doctoral degree (Ph.D., Ed.D., etc.)                                            0.030306
# Primary/elementary school                                                             0.025234
# Something else                                                                        0.017423
# Professional degree (JD, MD, etc.)                                                    0.015663
# Name: EdLevel, dtype: float64

# %%
df['EdLevel'].value_counts()[0:9].plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 性取向

# %%
df['Sexuality'].value_counts(normalize=True)
# Out:
# Straight / Heterosexual                                                           0.829835
# Prefer not to say                                                                 0.065350
# Bisexual                                                                          0.040562
# Gay or Lesbian                                                                    0.020762
# Prefer to self-describe:                                                          0.016210
# Queer                                                                             0.005919
# Bisexual;Straight / Heterosexual                                                  0.005318
# Bisexual;Queer                                                                    0.004236
# Straight / Heterosexual;Prefer to self-describe:                                  0.002539
# Gay or Lesbian;Queer                                                              0.002253
# ...

# %%
df['Sexuality'].value_counts()[0:6].plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 操作系统

# %%
df['OpSysProfessional use'].value_counts(normalize=True)
# Out:
# Windows                                                                                    0.254110
# macOS                                                                                      0.191457
# Linux-based                                                                                0.166924
# Linux-based;Windows                                                                        0.086057
# Linux-based;macOS                                                                          0.074897
# Windows;Windows Subsystem for Linux (WSL)                                                  0.058013
# Linux-based;Windows;Windows Subsystem for Linux (WSL)                                      0.045845
# macOS;Windows                                                                              0.035525
# Linux-based;macOS;Windows                                                                  0.023678
# ...

# %%
df['OpSysProfessional use'].value_counts()[0:5].plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='OpSysProfessional use'>

# %% [markdown]
# ## 年龄

# %%
df['Age'].value_counts(normalize=True)
# Out:
# 25-34 years old       0.396245
# 18-24 years old       0.234629
# 35-44 years old       0.197164
# 45-54 years old       0.074437
# Under 18 years old    0.054492
# 55-64 years old       0.027880
# 65 years or older     0.007809
# Prefer not to say     0.007344
# Name: Age, dtype: float64

# %%
df['Age'].value_counts()[0:8].plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 心理健康

# %%
df['MentalHealth'].value_counts(normalize=True)
# Out:
# None of the above                                                                                                                                                                                                                                                                                                                     0.705058
# Prefer not to say                                                                                                                                                                                                                                                                                                                     0.051695
# ...

# %%
df['MentalHealth'].value_counts()[0:8].plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 开发人员类型

# %%
df['DevType'].value_counts(normalize=True)
# Out:
# Developer, full-stack                                                                                                                                                                                                                                                                                                                                                                                                                  0.116505
# Developer, back-end                                                                                                                                                                                                                                                                                                                                                                                                                    0.086474
# ...

# %%
df['DevType'].value_counts()[0:5].plot(kind="barh")
# Out:
# <AxesSubplot:>
