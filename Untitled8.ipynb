# %%
import csv

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/JRC/Desktop/survey_results_public.csv")

# %%
print(df["LanguageHaveWorkedWith"])
# Out:
# 0                                                      NaN
# 1                                    JavaScript;TypeScript
# 2                        C#;C++;HTML/CSS;JavaScript;Python
# 3                             C#;JavaScript;SQL;TypeScript
# 4              C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#                                ...
# 73263    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                   HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                        C#;Delphi;VBA
# 73267          C#;JavaScript;Lua;PowerShell;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: object

# %%
len(df["LanguageHaveWorkedWith"])
# Out:
# 73268

# %%
df["LanguageHaveWorkedWith"]
# Out:
# 0                                                      NaN
# 1                                    JavaScript;TypeScript
# 2                        C#;C++;HTML/CSS;JavaScript;Python
# 3                             C#;JavaScript;SQL;TypeScript
# 4              C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#                                ...
# 73263    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                   HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                        C#;Delphi;VBA
# 73267          C#;JavaScript;Lua;PowerShell;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: object

# %%
    import numpy as np
import matplotlib.pyplot as plt

# %%
from collections import defaultdict, Counter
with open("C:/Users/JRC/Desktop/survey_results_public.csv") as f:
    reader = csv.DictReader(f)
    dev_type_info = {}
    total = 0
    for data in reader:
        dev_types = data['DevType'].split(';')
        for dev_type in dev_types:
            dev_type_info.setdefault(dev_type, {
                'total': 0,
                'language_counter': Counter()
            })
            languages = data['LanguageHaveWorkedWith'].split(';')
            dev_type_info[dev_type]['language_counter'].update(languages)
            dev_type_info[dev_type]['total'] += 1
                
for dev_type, info in dev_type_info.items():
    print(dev_type)
    for language, value in info['language_counter'].most_common(10):
        language_pct = (value / info['total']) * 100
        language_pct = round(language_pct, 2)
        print(f'----------{language}:{language_pct}%')
# Out:
# NA
# ----------Python:55.82%
# ----------JavaScript:52.69%
# ----------HTML/CSS:50.96%
# ----------Java:34.23%
# ----------C++:32.91%
# ----------SQL:29.98%
# ----------C:29.91%
# ----------Bash/Shell:22.39%
# ----------C#:21.21%
# ----------TypeScript:19.67%
# Data scientist or machine learning specialist
# ----------Python:86.89%
# ----------SQL:57.54%
# ----------JavaScript:44.86%
# ----------HTML/CSS:40.33%
# ----------Bash/Shell:37.06%
# ----------C++:29.03%
# ----------R:27.07%
# ----------Java:25.23%
# ----------C:21.7%
# ----------TypeScript:18.63%
# Developer, front-end
# ----------JavaScript:87.04%
# ----------HTML/CSS:75.83%
# ----------TypeScript:55.85%
# ----------SQL:52.44%
# ----------Python:34.56%
# ----------C#:30.09%
# ----------PHP:29.33%
# ----------Java:28.78%
# ----------Bash/Shell:25.09%
# ----------C++:16.77%
# Engineer, data
# ----------Python:72.25%
# ----------SQL:67.44%
# ----------JavaScript:53.72%
# ----------HTML/CSS:43.67%
# ...
